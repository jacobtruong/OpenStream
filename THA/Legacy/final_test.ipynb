# %%
from CompanyResearchAgent import *

# %%
import googlemaps

# %%
from GeminiAPI import *

# %%
from google import genai
print(genai.types)
# Out:
# <module 'google.genai.types' from 'g:\\Work\\OpenStream\\THA\\OpenStreamTHA\\Lib\\site-packages\\google\\genai\\types.py'>

# %%
gmaps = googlemaps.Client(key="AIzaSyDsns7U56HrugjUAoMoNIwuYlKiWSpaRWE")

# Geocode the address
geocode_result = gmaps.geocode("1067 Dandenong Road, Malvern East, 3145")

components = geocode_result[0]['address_components']

city = state = country = None

for component in components:
    types = component['types']
    if 'locality' in types:
        city = component['long_name']
    elif 'administrative_area_level_1' in types:
        state = component['long_name']
    elif 'country' in types:
        country = component['long_name']

{'city': city, 'state': state, 'country': country}
# Out:
# {'city': 'Malvern East', 'state': 'Victoria', 'country': 'Australia'}

# %%
from urllib.parse import urljoin, urlparse

# %%
urlparse("https://www.openstream.ai")
# Out:
# ParseResult(scheme='https', netloc='www.openstream.ai', path='', params='', query='', fragment='')

# %%
# COMPANY_NAME = "Texwin"
# COMPANY_URL = "https://www.texwin.com"

# %%
COMPANY_NAME = "OpenStream AI"
COMPANY_URL = "https://www.openstream.ai"

# %%
company_research_agent = CompanyResearchAgent(COMPANY_NAME, COMPANY_URL)

# %%
# Step by step testing
step_0 = company_research_agent._fetch_page_content(company_research_agent.base_url)
step_0
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <title>Visionary AI Virtual Assistants, AI Agents &amp; AI Avatars | Openstream.ai</title>
# <link href="https://openstream.ai/hubfs/opeenstream%20circle.svg" rel="shortcut icon"/>
# <meta content="Relationships matter. Build visionary multimodal, plan-based Conversational AI Virtual Assistants, AI Agents &amp; AI Avatars with Eva(TM) without scripts." name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Relationships matter. Build visionary multimodal, plan-based Conversational AI Virtual Assistants, AI Agents &amp; AI Avatars with Eva(TM) without scripts." property="og:description"/>
# <meta content="Visionary AI Virtual Assistants, AI Agents &amp; AI Avatars | Openstream.ai" property="og:title"/>
# ...

# %%
found_links = company_research_agent.find_key_page_urls()
# Out:
# 2025-08-15 20:50:49,921 - INFO - Searching for key page URLs on https://www.openstream.ai...
# 2025-08-15 20:50:50,096 - INFO - Found 'background' page link: https://openstream.ai/about-us (matched on text='about us' or href='https://openstream.ai/about-us')
# 2025-08-15 20:50:50,096 - INFO - Found 'contact' page link: https://openstream.ai/contact-us (matched on text='contact us' or href='https://openstream.ai/contact-us')

# %%
found_links
# Out:
# {'background': 'https://openstream.ai/about-us',
#  'products': 'https://www.openstream.ai',
#  'contact': 'https://openstream.ai/contact-us'}

# %%
found_links
# Out:
# {'background': 'https://openstream.ai/about-us',
#  'products': 'https://www.openstream.ai',
#  'contact': 'https://openstream.ai/contact-us'}

# %%
company_research_agent.base_url == found_links["contact"]
# Out:
# False

# %%
researched_content = company_research_agent.run_full_research()
# Out:
# 2025-08-15 20:23:21,214 - INFO -
# ----- Starting Full Research for OpenStream AI -----
# 2025-08-15 20:23:21,215 - INFO - Searching for key page URLs on https://www.openstream.ai...
# 2025-08-15 20:23:21,342 - INFO - Found 'background' page link: https://openstream.ai/about-us (matched on text='about us' or href='https://openstream.ai/about-us')
# 2025-08-15 20:23:21,342 - INFO - Found 'contact' page link: https://openstream.ai/contact-us (matched on text='contact us' or href='https://openstream.ai/contact-us')
# 2025-08-15 20:23:21,342 - INFO - Extracting main content text from https://openstream.ai/about-us...
# 2025-08-15 20:23:21,502 - INFO - Found a primary content tag (<main>, <article>, etc.). Extracting text from it.
# 2025-08-15 20:23:21,503 - INFO - Extracting main content text from https://www.openstream.ai...
# 2025-08-15 20:23:21,637 - INFO - Found a primary content tag (<main>, <article>, etc.). Extracting text from it.
# ...

# %%
from SummaryAgent import *

# %%
os.environ["GOOGLE_GEMINI_API_KEY"] = "AIzaSyBmQyeXCzbiDzSMHM264PQd91zF3tC_tOU"
os.environ["GOOGLE_MAPS_API_KEY"] = "AIzaSyDsns7U56HrugjUAoMoNIwuYlKiWSpaRWE"
os.environ["GEMINI_MODEL"] = "gemini-2.5-flash-lite"

# %%
SummaryAgent = SummaryAgent(
    company_name="OpenStream AI"
)

# %%
background_text = researched_content.get("background_text", "No background text available.")
products_text = researched_content.get("products_text", "No products text available.")
address_text = researched_content.get("physical_address", "No address text available.")

# %%
background_summary = SummaryAgent.summarise_background(background_text)
# Out:
# 2025-08-15 20:23:22,368 - INFO - Sending background text to LLM for summarisation...
# 2025-08-15 20:23:22,369 - INFO - AFC is enabled with max remote calls: 10.
# 2025-08-15 20:23:26,123 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-08-15 20:23:26,125 - INFO - AFC remote call 1 is done.
# 2025-08-15 20:23:26,125 - INFO - Successfully received summary from LLM.

# %%
print(background_summary)
# Out:
# OpenStream AI is a technology company focused on the development of advanced artificial intelligence solutions, specifically within the realm of conversational AI and virtual assistants. While a specific founding date is not explicitly stated, the company's operational history, as indicated by its recognition by industry analysts and awards, spans from at least 2020 to the present (2025). Key milestones in its trajectory include significant recognition from prominent analyst firms such as Gartner, Opus, and Tractica between 2020 and 2022. Further solidifying its market position, OpenStream AI was recognised as the sole visionary in Gartner's Magic Quadrant for Enterprise Conversational AI Platforms in both 2022 and 2023, indicating sustained innovation and strategic foresight in a competitive landscape.
#
# ...

# %%
products = SummaryAgent.list_products_services(products_text)
# Out:
# 2025-08-15 20:23:26,140 - INFO - Sending products text to LLM for extraction...
# 2025-08-15 20:23:26,140 - INFO - AFC is enabled with max remote calls: 10.
# 2025-08-15 20:23:29,942 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-08-15 20:23:29,943 - INFO - AFC remote call 1 is done.
# 2025-08-15 20:23:29,943 - INFO - Successfully extracted 12 products/services.

# %%
print(products)
# Out:
# - AI Virtual Agents: Advanced virtual assistants for websites or apps, designed to assist users without requiring pre-written scripts. Risk: Potential for over-reliance by businesses, leading to reduced human interaction in customer service.
# - AI Avatars: Digital representations of a brand's persona, fully trained and capable of multimodal interaction. Risk: Misrepresentation of brand values or identity if avatar behaviour is not meticulously managed.
# - AI Voice Agents: Sophisticated agents capable of natural, human-like conversation across multiple languages. Risk: Potential for misinterpretation of tone or sentiment, leading to customer dissatisfaction.
# - Conversational AI Solutions: Comprehensive solutions for building engaging AI-powered experiences for customers, employees, and prospects. Risk: Complexity in integration with existing enterprise systems and data security concerns.
# ...

# %%
from SatelliteAnalysisAgent import *

# %%
satellite_analysis_agent = SatelliteAnalysisAgent(company_name=COMPANY_NAME, company_address=address_text)

# %%
satellite_analysis = satellite_analysis_agent.run_satellite_analysis()
# Out:
# 2025-08-15 20:23:30,287 - INFO - Retrieving satellite image for address: 750 US 202 South Suite 410 Bridgewater, NJ 08807
# 2025-08-15 20:23:31,106 - INFO - Successfully saved satellite image to satellite_images\openstream_ai_satellite.png
# 2025-08-15 20:23:31,107 - INFO - Sending satellite image at satellite_images\openstream_ai_satellite.png to Vision LLM for analysis...
# 2025-08-15 20:23:31,113 - INFO - AFC is enabled with max remote calls: 10.
# 2025-08-15 20:23:35,584 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-08-15 20:23:35,588 - INFO - AFC remote call 1 is done.
# 2025-08-15 20:23:35,588 - INFO - Successfully received visual analysis from LLM.

# %%
print(satellite_analysis["analysis_text"])
# Out:
# Title: Satellite Image Analysis Report: OpenStream AI at 750 US 202 South Suite 410 Bridgewater, NJ 08807
#
# 1.  Flood Risk Assessment:
#     The property is not located near any visible bodies of water such as rivers, lakes, coastlines, large ponds, or drainage canals. Based on the aerial view, the property does not appear to be situated in a low-lying area prone to flooding. The surrounding terrain seems to be at a similar or higher elevation compared to the road systems.
#
# 2.  Building Condition Analysis:
# ...

# %%
address_text
# Out:
# '750 US 202 South Suite 410 Bridgewater, NJ 08807'

# %%
from ReportGeneratorAgent import *

# %%
report_generator_agent = ReportGeneratorAgent(COMPANY_NAME, address_text, background_summary, products, satellite_analysis)
# Out:
# 2025-08-15 19:53:28,236 - INFO - ReportGeneratorAgent initialized successfully.

# %%
report = report_generator_agent.generate_report()

# Save the report to a file
with open("company_report.md", "w") as f:
    f.write(report)
# Out:
# 2025-08-15 19:53:28,254 - INFO - Generating report...
# 2025-08-15 19:53:32,435 - INFO - Report generated successfully.

# %%
import os

# %%
os.environ["GOOGLE_GEMINI_API_KEY"] = "AIzaSyDIrEOLWpOmzqa16WWw7QOGqQIcni-bohA"
os.environ["GOOGLE_MAPS_API_KEY"] = "AIzaSyDsns7U56HrugjUAoMoNIwuYlKiWSpaRWE"
os.environ["GEMINI_MODEL"] = "gemini-2.5-flash-lite"

# %%
from GeminiAPI import *

# %%
llm = GeminiAPI()

# %%
content = r"""Global Contact us After"""

# %%
prompt = f"""
        You are given text scraped from a company's contact page. This text contains a lot of noise and/or scraping artifacts.
        Your task is to analyse the text and extract the full address of the company's location. If there are multiple addresses
        found in the text, return the first one or the one that is most relevant. Note that the full address might have varying
        formats depending on the country. Strictly return the full address without any additional commentary or text. DO NOT
        MAKE UP ADDRESSES, IF NONE ARE FOUND ON THE PAGE, SIMPLY RETURN AN EMPTY STRING.

        --- TEXT ---
        {content}
        """

# %%
print(prompt)
# Out:
#         You are given text scraped from a company's contact page. This text contains a lot of noise and/or scraping artifacts.
#         Your task is to analyse the text and extract the full address of the company's location. If there are multiple addresses
#         found in the text, return the first one or the one that is most relevant. Note that the full address might have varying
#         formats depending on the country. Strictly return the full address without any additional commentary or text. DO NOT
#         MAKE UP ADDRESSES, IF NONE ARE FOUND ON THE PAGE, SIMPLY RETURN AN EMPTY STRING.
#
#         --- TEXT ---
#         Global/Contact-us/After

# %%
llm.generate_content(prompt)
# Out:
# 2025-08-16 00:41:31,937 - INFO - AFC is enabled with max remote calls: 10.
# 2025-08-16 00:41:32,691 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 500 Internal Server Error"
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# File g:\Work\OpenStream\THA\GeminiAPI.py:35, in GeminiAPI.generate_content(self, prompt, image_bytes)
#      34 if not image_bytes:
# ---> 35     response = self.llm.models.generate_content(model=self.gemini_model, contents=prompt)
#      36 else:
#
# File g:\Work\OpenStream\THA\OpenStreamTHA\Lib\site-packages\google\genai\models.py:6138, in Models.generate_content(self, model, contents, config)
#    6137 i += 1
# -> 6138 response = self._generate_content(
#    6139     model=model, contents=contents, config=parsed_config
#    6140 )
# ...

# %%
from google import genai

client = genai.Client(api_key=os.getenv("GOOGLE_GEMINI_API_KEY"))

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Explain how AI works in a few words"
)
print(response.text.strip())
# Out:
# 2025-08-15 20:19:25,049 - INFO - AFC is enabled with max remote calls: 10.
# 2025-08-15 20:19:25,900 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-08-15 20:19:25,902 - INFO - AFC remote call 1 is done.
# AI learns from data to make predictions or decisions.
